# %% [markdown]
# <a href="https://colab.research.google.com/github/Roberthoed172425/Python_2023/blob/main/12_EDA_parte1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exploratory Data Analyst (EDA)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Primera Parte: Validación de Datos

# %%
#Cargamos nuestra data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

culqi_df = pd.read_excel("/content/drive/MyDrive/1 Bootcamp_Python_DSRP/Clase del profesor/6TA CLASE/Copia de Ejercicio 2_.xlsx")

culqi_df.head(3)
# Out:
#   FECHA VENTA CANAL VENTA  RUC CLIENTE      VENDEDOR  VENTA ACTIVA  \
# 0  2022-01-02      BANCOS  BJDCDAEDCCC  JUAN CORNEJO             0
# 1  2022-01-02    ORGANICO  BJFJBHAGGCD           ND              0
# 2  2022-01-02      BANCOS     DCGGBCAG  ROSAS STUART             0
#
#   FECHA ACTIVACION  FLUJO MES VENTA      GIRO ECONOMICO DEPARTAMENTO  \
# 0              NaT              NaN  TELECOMUNICACIONES         LIMA
# 1              NaT              NaN        RESTAURANTES         LIMA
# 2              NaT              NaN            SERVICIO         LIMA
#
#   TIPO PRODUCTO    PRODUCTO
# 0        ONLINE  CULQI LINK
# 1       OFFLINE   CULQI PRO
# 2       OFFLINE   CULQI PRO

# %%
culqi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22446 entries, 0 to 22445
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   FECHA VENTA       22446 non-null  datetime64[ns]
#  1   CANAL VENTA       22446 non-null  object
#  2   RUC CLIENTE       22446 non-null  object
#  3   VENDEDOR          22446 non-null  object
#  4   VENTA ACTIVA      22446 non-null  int64
#  5   FECHA ACTIVACION  14067 non-null  datetime64[ns]
#  6   FLUJO MES VENTA   5426 non-null   float64
#  7   GIRO ECONOMICO    22446 non-null  object
#  8   DEPARTAMENTO      21001 non-null  object
#  9   TIPO PRODUCTO     22446 non-null  object
#  10  PRODUCTO          22446 non-null  object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(7)
# memory usage: 1.9+ MB

# %% [markdown]
# ### 1.¿Qué tipo de datos son las variables del conjunto de datos?

# %%
culqi_df.dtypes
# Out:
# FECHA VENTA         datetime64[ns]
# CANAL VENTA                 object
# RUC CLIENTE                 object
# VENDEDOR                    object
# VENTA ACTIVA                 int64
# FECHA ACTIVACION    datetime64[ns]
# FLUJO MES VENTA            float64
# GIRO ECONOMICO              object
# DEPARTAMENTO                object
# TIPO PRODUCTO               object
# PRODUCTO                    object
# dtype: object

# %% [markdown]
# ### 2.¿Cuantas Variables de cada tipo de dato tenemos en el conjunto de datos?

# %%
culqi_df.dtypes.value_counts()
# Out:
# object            7
# datetime64[ns]    2
# int64             1
# float64           1
# dtype: int64

# %% [markdown]
# ### 3.¿Cuantas variables y observaciones tenemos en el conjunto de datos?

# %%
culqi_df.shape
# Out:
# (22446, 11)

# %% [markdown]
# ### 4.¿Existen valores nulos explicitos en el conjunto de datos??

# %%
culqi_df.isnull().head(5)
# Out:
#    FECHA VENTA  CANAL VENTA  RUC CLIENTE  VENDEDOR  VENTA ACTIVA  \
# 0        False        False        False     False         False
# 1        False        False        False     False         False
# 2        False        False        False     False         False
# 3        False        False        False     False         False
# 4        False        False        False     False         False
#
#    FECHA ACTIVACION  FLUJO MES VENTA  GIRO ECONOMICO  DEPARTAMENTO  \
# 0              True             True           False         False
# 1              True             True           False         False
# 2              True             True           False         False
# 3              True             True           False         False
# 4              True             True           False         False
#
#    TIPO PRODUCTO  PRODUCTO
# 0          False     False
# 1          False     False
# 2          False     False
# 3          False     False
# 4          False     False

# %%
culqi_df.isnull().any()
# Out:
# FECHA VENTA         False
# CANAL VENTA         False
# RUC CLIENTE         False
# VENDEDOR            False
# VENTA ACTIVA        False
# FECHA ACTIVACION     True
# FLUJO MES VENTA      True
# GIRO ECONOMICO      False
# DEPARTAMENTO         True
# TIPO PRODUCTO       False
# PRODUCTO            False
# dtype: bool

# %% [markdown]
# ### 5.De tener observaciones con valores nulos, ¿cuántas tenemos por cada variable?

# %%
culqi_df.isnull().sum()
# Out:
# FECHA VENTA             0
# CANAL VENTA             0
# RUC CLIENTE             0
# VENDEDOR                0
# VENTA ACTIVA            0
# FECHA ACTIVACION     8379
# FLUJO MES VENTA     17020
# GIRO ECONOMICO          0
# DEPARTAMENTO         1445
# TIPO PRODUCTO           0
# PRODUCTO                0
# dtype: int64

# %% [markdown]
# ### 6.¿Cuántos valores nulos tenemos en total en el conjunto de datos?

# %%
culqi_df.isnull().sum().sum()
# Out:
# 26844

# %% [markdown]
# ### 7.¿Cuál es la proporción de valores nulos por cada variable?

# %%
culqi_df.isnull().melt()
# Out:
#            variable  value
# 0       FECHA VENTA  False
# 1       FECHA VENTA  False
# 2       FECHA VENTA  False
# 3       FECHA VENTA  False
# 4       FECHA VENTA  False
# ...             ...    ...
# 246901     PRODUCTO  False
# 246902     PRODUCTO  False
# 246903     PRODUCTO  False
# 246904     PRODUCTO  False
# 246905     PRODUCTO  False
#
# [246906 rows x 2 columns]

# %%
df = culqi_df.isnull().melt()

sns.displot(data=df,
            y='variable',
            hue='value',
            multiple='fill',
            aspect=2)
plt.show()

# %%
total = culqi_df.isnull().sum().sort_values(ascending = False)
percent = (culqi_df.isnull().sum() / culqi_df.isnull().count()).sort_values(ascending = False)
missing_data = pd.concat([total, percent], axis = 1, keys = ['Total', 'Percent'])
missing_data.head(15)
# Out:
#                   Total   Percent
# FLUJO MES VENTA   17020  0.758264
# FECHA ACTIVACION   8379  0.373296
# DEPARTAMENTO       1445  0.064377
# FECHA VENTA           0  0.000000
# CANAL VENTA           0  0.000000
# RUC CLIENTE           0  0.000000
# VENDEDOR              0  0.000000
# VENTA ACTIVA          0  0.000000
# GIRO ECONOMICO        0  0.000000
# TIPO PRODUCTO         0  0.000000
# PRODUCTO              0  0.000000

# %% [markdown]
# ### 8.¿Como podemos visualizar los valores nulos en todo el conjunto de datos?

# %%
df = culqi_df.isnull().transpose()

sns.heatmap(data=df)
# Out:
# <Axes: >

# %% [markdown]
# ### 9.¿Cuantas observaciones perdemos si eliminamos los datos faltantes?

# %%
#Primero recordemos cuantos datos tenemos
culqi_df.shape
# Out:
# (22446, 11)

# %%
cdf = culqi_df.dropna()

# %%
cdf.shape
# Out:
# (5034, 11)

# %% [markdown]
# ## Segunda Parte: Conteo y proporciones

# %% [markdown]
# ### ¿Que estadisticos describen el conjunto de datos?

# %%
cdf.describe()
# Out:
#        VENTA ACTIVA  FLUJO MES VENTA
# count        5034.0      5034.000000
# mean            1.0       964.364323
# std             0.0       792.355073
# min             1.0       100.000000
# 25%             1.0       305.000000
# 50%             1.0       689.500000
# 75%             1.0      1469.750000
# max             1.0      2997.000000

# %% [markdown]
# ### Todas las Variables

# %%
cdf.describe(include='all')
# Out:
# <ipython-input-19-2fa95dc1ebb9>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   cdf.describe(include='all')
# <ipython-input-19-2fa95dc1ebb9>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   cdf.describe(include='all')
#                 FECHA VENTA CANAL VENTA  RUC CLIENTE VENDEDOR  VENTA ACTIVA  \
# count                  5034        5034         5034     5034        5034.0
# unique                  326           4         4445      643           NaN
# top     2022-12-29 00:00:00     DEALERS  BJFJHHCHEDG      ND            NaN
# freq                     66        3326           27      150           NaN
# first   2022-01-03 00:00:00         NaN          NaN      NaN           NaN
# last    2022-12-31 00:00:00         NaN          NaN      NaN           NaN
# mean                    NaN         NaN          NaN      NaN           1.0
# std                     NaN         NaN          NaN      NaN           0.0
# min                     NaN         NaN          NaN      NaN           1.0
# 25%                     NaN         NaN          NaN      NaN           1.0
# 50%                     NaN         NaN          NaN      NaN           1.0
# 75%                     NaN         NaN          NaN      NaN           1.0
# max                     NaN         NaN          NaN      NaN           1.0
#
#            FECHA ACTIVACION  FLUJO MES VENTA GIRO ECONOMICO DEPARTAMENTO  \
# count                  5034      5034.000000           5034         5034
# unique                  347              NaN              6           29
# top     2022-12-30 00:00:00              NaN       COMERCIO         LIMA
# freq                     72              NaN           2027         2766
# first   2021-04-16 00:00:00              NaN            NaN          NaN
# last    2022-12-31 00:00:00              NaN            NaN          NaN
# mean                    NaN       964.364323            NaN          NaN
# std                     NaN       792.355073            NaN          NaN
# min                     NaN       100.000000            NaN          NaN
# 25%                     NaN       305.000000            NaN          NaN
# 50%                     NaN       689.500000            NaN          NaN
# 75%                     NaN      1469.750000            NaN          NaN
# max                     NaN      2997.000000            NaN          NaN
#
#        TIPO PRODUCTO    PRODUCTO
# count           5034        5034
# unique             2           6
# top          OFFLINE  CULQI FULL
# freq            4815        3690
# first            NaN         NaN
# last             NaN         NaN
# mean             NaN         NaN
# std              NaN         NaN
# min              NaN         NaN
# 25%              NaN         NaN
# 50%              NaN         NaN
# 75%              NaN         NaN
# max              NaN         NaN

# %% [markdown]
# ###Solo las numericas

# %%
cdf.describe(include=[np.number])
# Out:
#        VENTA ACTIVA  FLUJO MES VENTA
# count        5034.0      5034.000000
# mean            1.0       964.364323
# std             0.0       792.355073
# min             1.0       100.000000
# 25%             1.0       305.000000
# 50%             1.0       689.500000
# 75%             1.0      1469.750000
# max             1.0      2997.000000

# %% [markdown]
# ###Solo Categoricas 1

# %%
cdf.describe(include=object)
# Out:
#        CANAL VENTA  RUC CLIENTE VENDEDOR GIRO ECONOMICO DEPARTAMENTO  \
# count         5034         5034     5034           5034         5034
# unique           4         4445      643              6           29
# top        DEALERS  BJFJHHCHEDG      ND        COMERCIO         LIMA
# freq          3326           27      150           2027         2766
#
#        TIPO PRODUCTO    PRODUCTO
# count           5034        5034
# unique             2           6
# top          OFFLINE  CULQI FULL
# freq            4815        3690

# %%
cdf.astype({
        'CANAL VENTA':'category',
        'RUC CLIENTE':'category',
        'VENDEDOR':'category',
        'GIRO ECONOMICO':'category',
        'DEPARTAMENTO':'category',
        'TIPO PRODUCTO':'category',
        'PRODUCTO':'category'
    })
# Out:
#       FECHA VENTA CANAL VENTA  RUC CLIENTE          VENDEDOR  VENTA ACTIVA  \
# 13920  2022-01-17     DEALERS     GJFGCACJ   OMAR BUSTAMANTE             1
# 13921  2022-02-16     DEALERS     DHAGICHD     MARCO CHANAME             1
# 13922  2022-02-17     DEALERS     GEDBJJBA      RUTH PEREYRA             1
# 13924  2022-03-22      BANCOS  BJFJCFHGJFA     JORGE SALAZAR             1
# 13925  2022-05-06     DEALERS  AJGFBDIDHCI      ANGIE MOLINA             1
# ...           ...         ...          ...               ...           ...
# 19341  2022-07-07     DEALERS  AJDGDGAHFEJ  GORETTY URUPEQUE             1
# 19342  2022-08-12     DEALERS     GCDEHEAG    JOSE HERNANDEZ             1
# 19343  2022-10-12     DEALERS     DACDDIFJ      MARTIN ANTON             1
# 19344  2022-12-29     DEALERS     DHDJDAIE       ELBA ZAPATA             1
# 19345  2022-11-07      BANCOS  BJFJIGGHGAH       SUSAN FELIX             1
#
#       FECHA ACTIVACION  FLUJO MES VENTA      GIRO ECONOMICO DEPARTAMENTO  \
# 13920       2022-01-25            100.0            SERVICIO         LIMA
# 13921       2022-02-25            100.0            COMERCIO         LIMA
# 13922       2022-02-27            100.0          TRANSPORTE         LIMA
# 13924       2022-03-29            100.0        RESTAURANTES       CALLAO
# 13925       2022-05-25            100.0               OTROS         LIMA
# ...                ...              ...                 ...          ...
# 19341       2022-07-08           2991.0            COMERCIO   LAMBAYEQUE
# 19342       2022-08-12           2992.0            COMERCIO          ICA
# 19343       2022-10-12           2995.0            COMERCIO         LIMA
# 19344       2022-12-29           2996.0            COMERCIO        PIURA
# 19345       2022-11-08           2997.0  TELECOMUNICACIONES         LIMA
#
#       TIPO PRODUCTO    PRODUCTO
# 13920       OFFLINE   CULQI PRO
# 13921       OFFLINE   CULQI PRO
# 13922       OFFLINE   CULQI PRO
# 13924       OFFLINE   CULQI PRO
# 13925       OFFLINE   CULQI PRO
# ...             ...         ...
# 19341       OFFLINE  CULQI FULL
# 19342       OFFLINE  CULQI FULL
# 19343       OFFLINE  CULQI FULL
# 19344       OFFLINE  CULQI FULL
# 19345       OFFLINE  CULQI FULL
#
# [5034 rows x 11 columns]

# %% [markdown]
# ### ¿Como visualizo los conteos?

# %% [markdown]
# ### Pandas

# %%
df = cdf['CANAL VENTA'].value_counts()





'''
plt.bar(plot.index,plot.values)
plt.show()
'''
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-b041adda9c1c> in <cell line: 3>()
#       1 df = cdf['CANAL VENTA'].value_counts()
#       2
# ----> 3 plt.bar(plot.index,plot.values)
#       4 plt.show()
#
# NameError: name 'plot' is not defined

# %%
bars = plt.bar(plot.index,plot.values)

plt.bar_label(bars)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-79c2af4a6729> in <cell line: 1>()
# ----> 1 bars = plt.bar(plot.index,plot.values)
#       2
#       3 plt.bar_label(bars)
#       4 plt.show()
#
# NameError: name 'plot' is not defined

# %% [markdown]
# ### Seaborn

# %%
sns.catplot(
    data=cdf,
    x='CANAL VENTA',
    kind='count'
)
plt.show()

# %%
#realizamos una tabla para contar
df = cdf['CANAL VENTA'].value_counts(sort=True).reset_index(name='count')


sns.barplot(data=df,
            x='index',
            y='count')

# %% [markdown]
# ### ¿Cómo visualizar las proporciones?

# %%
cdf['x']=''

cdf.info()

# %%
sns.displot(
    data=cdf,
    x='x',
    hue='CANAL VENTA',
    multiple='fill'
)

plt.show()

# %% [markdown]
# ## Tercera Parte: Medidas de Tendencia Central

# %% [markdown]
# ### PROMEDIO

# %%
cdf.mean()

# %% [markdown]
# ### MEDIANA

# %%
cdf.median()

# %% [markdown]
# ### MODE

# %%
cdf.mode()

# %%
#moda para variables categoricas:
cdf.describe(include=object)

# %% [markdown]
# ## Cuarta Parte: Medidas de Dispersión
#
# ![medida.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![asimetria_.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![curtosis.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### Rango
# *  La diferencia entre el valor máximo y valor mínimo

# %%
#Valor maximo:
cdf['FLUJO MES VENTA'].max(numeric_only=True)

# %%
#Valor minimo:
cdf.min(numeric_only=True)

# %%
#Rango de variales
cdf.max(numeric_only=True) - cdf.min(numeric_only=True)

# %% [markdown]
# ### Desviación Estandar
# *  La dispersión media de una variable

# %%
cdf.std(numeric_only=True)

# %% [markdown]
# ### Rango intercuartílico
# *  Comprenden +-25% de los datos respecto a la mediana

# %%
cdf.quantile(0.25,numeric_only=True)

# %%
cdf.quantile(0.50,numeric_only=True)

# %%
cdf.quantile(0.75,numeric_only=True)

# %%
#BOXPLOT

sns.boxplot(
    data=cdf,
    x='FLUJO MES VENTA'
)

plt.axvline(
    x=cdf['FLUJO MES VENTA'].mean(),
    color='red',
    linestyle='dashed',
    linewidth=2
)
plt.show()

# %% [markdown]
# ### Visualizando la distribución de una variable

# %%
sns.histplot(
    data=cdf,
    x='FLUJO MES VENTA',
)

plt.axvline(
    x=cdf['FLUJO MES VENTA'].mean(),
    color='red',
    linestyle='dashed',
    linewidth=2
)
plt.show()

# %%
#BOXPLOT

sns.boxplot(
    data=cdf,
    x='FLUJO MES VENTA'
)
